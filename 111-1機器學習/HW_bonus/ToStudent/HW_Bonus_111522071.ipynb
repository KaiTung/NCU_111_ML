# %% [markdown]
# # Load AOI dataset

# %%
#read csv
import pandas as pd
AOI_data = pd.read_csv('train.csv')

# %%
import cv2
#Observe the number of data of each class
label = []
for i in range(6):
  temp = AOI_data[AOI_data['Label'] == i]
  label.append(temp.reset_index())

# %%
train_images = []
train_label = []
test_images = []
test_label = []
for i in range(6):
  #Split the test data (You cannot change the code of this part. We will use these test sets for scoring)
  images_temp = []
  label_temp = [i] * 20
  for j in range(20):
    img = cv2.imread('./train_images/'+label[i]['ID'][j])
    images_temp.append(cv2.resize(img,(224,224), cv2.INTER_AREA))
  test_images += images_temp
  test_label += label_temp

  #Augment data to make the number of training data of each class is the same
  #Write the code

  train_images += images_temp
  train_label += label_temp

# %%
#Change list to array
import numpy as np
from sklearn.utils import shuffle
x_train = np.array(train_images)
x_test = np.array(test_images)
y_train = np.array(train_label)
y_test = np.array(test_label)

# %%
#Shuffle the dataset
import random
x_train , y_train = shuffle(x_train, y_train, random_state=random.seed())

# %% [markdown]
# # Check the shape of data

# %%
print('x_train shape: ', x_train.shape)
print('x_test shape: ', x_test.shape)
# Out:
# x_train shape:  (120, 224, 224, 3)
# x_test shape:  (120, 224, 224, 3)

# %% [markdown]
# # Check the shape of label

# %%
print('y_train shape:',y_train.shape)
print('y_test shape:', y_test.shape)
# Out:
# y_train shape: (120,)
# y_test shape: (120,)

# %% [markdown]
# # Check the content of labels

# %%
print(y_train[0:10])
# Out:
# [1 4 4 3 2 1 1 3 0 4]

# %% [markdown]
# # Min-max normalization

# %%
x_train_norm = x_train.astype('float32')/255
x_test_norm = x_test.astype('float32')/255

# %%
print(x_train_norm[0][0][0])
# Out:
# [0.69411767 0.69411767 0.69411767]

# %% [markdown]
# # Use One-hot encoding for the label

# %%
from tensorflow.keras import utils

# Before transfer....
print(y_train[0])
# Out:
# 1

# %%
# One-hot encoding...
y_train_onehot = utils.to_categorical(y_train, 6)
y_test_onehot = utils.to_categorical(y_test, 6)
# After transfer...
print(y_train_onehot[0])
# Out:
# [0. 1. 0. 0. 0. 0.]

# %% [markdown]
# # Build CNN Model

# %%
import tensorflow as tf
import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D

import tensorflow.keras.applications as tensorflow_model

# %%
vgg16 = tensorflow_model.VGG16(weights = 'imagenet',include_top=False,input_shape=(224,224,3)) #Please fill in the model parameters.

# %%
#Build the model
num_classes = 6
x = vgg16.layers[-1].output
x = Flatten()(x)
x = Dropout(0.4)(x)
x = Dense(num_classes,activation = 'softmax')(x)

# Create your own model 
cnn = keras.models.Model(inputs = vgg16.input, outputs=x) 
cnn.summary()
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten_6 (Flatten)         (None, 25088)             0
#
#  dropout_6 (Dropout)         (None, 25088)             0
#
#  dense_6 (Dense)             (None, 6)                 150534
#
# =================================================================
# Total params: 14,865,222
# Trainable params: 14,865,222
# Non-trainable params: 0
# _________________________________________________________________

# %%
# The setting of training model #
adam = tf.optimizers.Adam(0.0001)
cnn.compile(optimizer = adam,loss = 'categorical_crossentropy', metrics = ['acc'])

# %%
# Train the model #
history = cnn.fit(x=x_train_norm,y=y_train_onehot,batch_size=32,epochs=30,validation_split=0.1)
# Out:
# Epoch 1/25
# 4/4 [==============================] - 34s 8s/step - loss: 1.5979 - acc: 0.3796 - val_loss: 1.2532 - val_acc: 0.4167
# Epoch 2/25
# 4/4 [==============================] - 33s 8s/step - loss: 1.4421 - acc: 0.4537 - val_loss: 1.2417 - val_acc: 0.4167
# Epoch 3/25
# 4/4 [==============================] - 32s 8s/step - loss: 1.1095 - acc: 0.5556 - val_loss: 0.9807 - val_acc: 0.6667
# Epoch 4/25
# 4/4 [==============================] - 32s 8s/step - loss: 0.8798 - acc: 0.7037 - val_loss: 1.0656 - val_acc: 0.6667
# Epoch 5/25
# 4/4 [==============================] - 32s 8s/step - loss: 0.7062 - acc: 0.7500 - val_loss: 1.1791 - val_acc: 0.6667
# Epoch 6/25
# 4/4 [==============================] - 32s 8s/step - loss: 0.5378 - acc: 0.8333 - val_loss: 0.7949 - val_acc: 0.7500
# Epoch 7/25
# 4/4 [==============================] - 32s 8s/step - loss: 0.4354 - acc: 0.8426 - val_loss: 1.0455 - val_acc: 0.7500
# Epoch 8/25
# 4/4 [==============================] - 32s 8s/step - loss: 0.5537 - acc: 0.8333 - val_loss: 0.8889 - val_acc: 0.6667
# Epoch 9/25
# 4/4 [==============================] - 32s 8s/step - loss: 0.6354 - acc: 0.7778 - val_loss: 0.6518 - val_acc: 0.6667
# Epoch 10/25
# 4/4 [==============================] - 32s 8s/step - loss: 0.5474 - acc: 0.7963 - val_loss: 0.5547 - val_acc: 0.7500
# Epoch 11/25
# 4/4 [==============================] - 32s 8s/step - loss: 0.4679 - acc: 0.8333 - val_loss: 0.7366 - val_acc: 0.7500
# Epoch 12/25
# 4/4 [==============================] - 32s 8s/step - loss: 0.3716 - acc: 0.8241 - val_loss: 1.0011 - val_acc: 0.6667
# Epoch 13/25
# 4/4 [==============================] - 32s 8s/step - loss: 0.3386 - acc: 0.8611 - val_loss: 0.5539 - val_acc: 0.8333
# Epoch 14/25
# 4/4 [==============================] - 32s 8s/step - loss: 0.3181 - acc: 0.8704 - val_loss: 1.1146 - val_acc: 0.6667
# Epoch 15/25
# 4/4 [==============================] - 32s 8s/step - loss: 0.3733 - acc: 0.8981 - val_loss: 0.6554 - val_acc: 0.6667
# Epoch 16/25
# 4/4 [==============================] - 32s 8s/step - loss: 0.3485 - acc: 0.8889 - val_loss: 0.7689 - val_acc: 0.7500
# Epoch 17/25
# 4/4 [==============================] - 32s 8s/step - loss: 0.3015 - acc: 0.9167 - val_loss: 0.4466 - val_acc: 0.9167
# Epoch 18/25
# 4/4 [==============================] - 32s 8s/step - loss: 0.3304 - acc: 0.8981 - val_loss: 0.9270 - val_acc: 0.7500
# Epoch 19/25
# 4/4 [==============================] - 32s 8s/step - loss: 0.3400 - acc: 0.9167 - val_loss: 0.8824 - val_acc: 0.7500
# Epoch 20/25
# 4/4 [==============================] - 32s 8s/step - loss: 0.2090 - acc: 0.9352 - val_loss: 0.6998 - val_acc: 0.7500
# Epoch 21/25
# 4/4 [==============================] - 33s 8s/step - loss: 0.3010 - acc: 0.8889 - val_loss: 0.9374 - val_acc: 0.7500
# Epoch 22/25
# 4/4 [==============================] - 33s 8s/step - loss: 0.4111 - acc: 0.8981 - val_loss: 0.8016 - val_acc: 0.7500
# Epoch 23/25
# 4/4 [==============================] - 32s 8s/step - loss: 0.3801 - acc: 0.8704 - val_loss: 1.0510 - val_acc: 0.7500
# Epoch 24/25
# 4/4 [==============================] - 32s 8s/step - loss: 0.4188 - acc: 0.8333 - val_loss: 0.9021 - val_acc: 0.7500
# Epoch 25/25
# 4/4 [==============================] - 32s 8s/step - loss: 0.4059 - acc: 0.8426 - val_loss: 0.6348 - val_acc: 0.7500

# %% [markdown]
# # Use test set to evalute the model

# %%
# evaluate
test_loss,test_val = cnn.evaluate(x_test_norm,y_test_onehot)
print('The loss of testing data:', test_loss)
print('The accuracy of testing data:', test_val)
# Out:
# 4/4 [==============================] - 6s 1s/step - loss: 0.2776 - acc: 0.9000
# The loss of testing data: 0.27761512994766235
# The accuracy of testing data: 0.8999999761581421

# %%
# predict
predict_prop = cnn.predict(x_test_norm)
print('第一筆測試資料的預測機率', predict_prop[0])
# Out:
# 4/4 [==============================] - 6s 1s/step
# 第一筆測試資料的預測機率 [0.17887469 0.00274437 0.76536924 0.04305771 0.00866015 0.00129398]
